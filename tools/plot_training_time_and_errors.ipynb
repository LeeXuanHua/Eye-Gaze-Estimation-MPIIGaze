# %%
lenet_error = {
    "0": 4.201235771179199,
    "1": 5.857380390167236,
    "2": 6.206435680389404,
    "3": 6.56096887588501,
    "4": 5.819915294647217,
    "5": 6.3475799560546875,
    "6": 5.868472099304199,
    "7": 7.9688591957092285,
    "8": 6.652606010437012,
    "9": 7.961040496826172,
    "10": 6.87950325012207,
    "11": 5.874270915985107,
    "12": 6.095603942871094,
    "13": 6.640603065490723,
    "14": 5.9826836585998535
}

lenet_time = {
    "0": 4.50,
    "1": 4.50,
    "2": 4.70,
    "3": 4.60,
    "4": 4.60,
    "5": 4.60,
    "6": 4.60,
    "7": 4.60,
    "8": 4.60,
    "9": 4.60,
    "10": 4.60,
    "11": 4.60,
    "12": 4.60,
    "13": 4.60,
    "14": 4.60
}

resnet_error = {
    "0": 4.036035537719727,
    "1": 4.759617805480957,
    "2": 6.224761486053467,
    "3": 5.100761413574219,
    "4": 6.021407604217529,
    "5": 6.4100799560546875,
    "6": 5.680694580078125,
    "7": 6.351699352264404,
    "8": 6.108707904815674,
    "9": 5.91240930557251,
    "10": 5.642880916595459,
    "11": 6.248713970184326,
    "12": 5.415345668792725,
    "13": 6.231785774230957,
    "14": 5.865034580230713
}

resnet_time = {
    "0": 8.725,
    "1": 8.875,
    "2": 8.775,
    "3": 9.000,
    "4": 9.225,
    "5": 9.425,
    "6": 9.400,
    "7": 9.150,
    "8": 9.300,
    "9": 9.500,
    "10": 9.275,
    "11": 9.600,
    "12": 9.500,
    "13": 9.675,
    "14": 9.550
}

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Create a bar chart for lenet error, varying the colours
ax1.bar(lenet_error.keys(), lenet_error.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax1.hlines(np.mean(list(lenet_error.values())), -1, 15, colors='k', linestyles='dashed')
ax1.set_ylim([0, 10])
ax1.set_xlabel("Person ID")
ax1.set_ylabel("Angle Error [deg]")
ax1.set_title(f"LeNet \nMean Angle Error: {np.mean(list(lenet_error.values())):.2f} deg")

# Create a bar chart for resnet error, varying the colours
ax2.bar(resnet_error.keys(), resnet_error.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax2.hlines(np.mean(list(resnet_error.values())), -1, 15, colors='k', linestyles='dashed')
ax2.set_ylim([0, 10])
ax2.set_xlabel("Person ID")
ax2.set_ylabel("Angle Error [deg]")
ax2.set_title(f"ResNet-preact-8 \nMean Angle Error: {np.mean(list(resnet_error.values())):.2f} deg")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Create a bar chart for lenet time, varying the colours
ax1.bar(lenet_time.keys(), lenet_time.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax1.hlines(np.mean(list(lenet_time.values())), -1, 15, colors='k', linestyles='dashed')
ax1.set_ylim([0, 10])
ax1.set_xlabel("Person ID")
ax1.set_ylabel("Training time [s/epoch]")
ax1.set_title(f"LeNet \nMean Training Time {np.mean(list(lenet_time.values())):.2f} s/epoch")

# Create a bar chart for resnet time, varying the colours
ax2.bar(resnet_time.keys(), resnet_time.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax2.hlines(np.mean(list(resnet_time.values())), -1, 15, colors='k', linestyles='dashed')
ax2.set_ylim([0, 10])
ax2.set_xlabel("Person ID")
ax2.set_ylabel("Training time [s/epoch]")
ax2.set_title(f"ResNet-preact-8 \nMean Training Time {np.mean(list(resnet_time.values())):.2f} s/epoch")

plt.show()

# %%
alexnet_error = {
    "00": 2.5926711559295654,
    "01": 5.880463123321533,
    "02": 5.201772212982178,
    "03": 5.638153553009033,
    "04": 4.7275776863098145,
    "05": 4.894957542419434,
    "06": 3.4403390884399414,
    "07": 5.164022922515869,
    "08": 5.124176979064941,
    "09": 5.189162254333496,
    "10": 5.192043781280518,
    "11": 5.762932300567627,
    "12": 5.050137519836426,
    "13": 5.1160736083984375,
    "14": 7.457568168640137,
}

alexnet_time = {
    "00": 132, 
    "01": 131, 
    "02": 131, 
    "03": 131, 
    "04": 131, 
    "05": 131, 
    "06": 131, 
    "07": 131, 
    "08": 130, 
    "09": 131, 
    "10": 131, 
    "11": 131, 
    "12": 132, 
    "13": 131, 
    "14": 131
}

resnet_error = {
    "00": 2.1106247901916504,
    "01": 5.465665817260742,
    "02": 5.1382951736450195,
    "03": 6.074862003326416,
    "04": 3.6258327960968018,
    "05": 4.259786605834961,
    "06": 3.0125956535339355,
    "07": 4.566280841827393,
    "08": 4.682868480682373,
    "09": 5.128609657287598,
    "10": 5.466821670532227,
    "11": 6.558365345001221,
    "12": 4.866367340087891,
    "13": 4.26247501373291,
    "14": 7.144346237182617,
}

resnet_time = {
    "00": 77, 
    "01": 77, 
    "02": 77, 
    "03": 79, 
    "04": 110, 
    "05": 112, 
    "06": 112, 
    "07": 110, 
    "08": 111, 
    "09": 112, 
    "10": 66, 
    "11": 66, 
    "12": 66, 
    "13": 66, 
    "14": 69,
}

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Create a bar chart for Alexnet error, varying the colours
ax1.bar(alexnet_error.keys(), alexnet_error.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax1.hlines(np.mean(list(alexnet_error.values())), -1, 15, colors='k', linestyles='dashed')
ax1.set_ylim([0, 10])
ax1.set_xlabel("Person ID")
ax1.set_ylabel("Angle Error [deg]")
ax1.set_title(f"Alexnet \nMean Angle Error: {np.mean(list(alexnet_error.values())):.2f} deg")

# Create a bar chart for resnet error, varying the colours
ax2.bar(resnet_error.keys(), resnet_error.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax2.hlines(np.mean(list(resnet_error.values())), -1, 15, colors='k', linestyles='dashed')
ax2.set_ylim([0, 10])
ax2.set_xlabel("Person ID")
ax2.set_ylabel("Angle Error [deg]")
ax2.set_title(f"ResNet-14 \nMean Angle Error: {np.mean(list(resnet_error.values())):.2f} deg")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Create a bar chart for Alexnet time, varying the colours
ax1.bar(alexnet_time.keys(), alexnet_time.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax1.hlines(np.mean(list(alexnet_time.values())), -1, 15, colors='k', linestyles='dashed')
ax1.set_ylim([0, 150])
ax1.set_xlabel("Person ID")
ax1.set_ylabel("Training time [s/epoch]")
ax1.set_title(f"Alexnet \nMean Training Time {np.mean(list(alexnet_time.values())):.2f} s/epoch")

# Create a bar chart for resnet time, varying the colours
ax2.bar(resnet_time.keys(), resnet_time.values(), color=['red', 'blue', 'purple', 'green', 'lavender', 'orange', 'yellow', 'pink', 'cyan', 'magenta', 'brown', 'teal', 'coral', 'lightblue', 'lime'])
ax2.hlines(np.mean(list(resnet_time.values())), -1, 15, colors='k', linestyles='dashed')
ax2.set_ylim([0, 150])
ax2.set_xlabel("Person ID")
ax2.set_ylabel("Training time [s/epoch]")
ax2.set_title(f"ResNet-14 \nMean Training Time {np.mean(list(resnet_time.values())):.2f} s/epoch")

plt.show()
